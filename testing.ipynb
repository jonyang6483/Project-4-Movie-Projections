# %%
# Import the modules
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
# from sklearn.preprocessing import StandardScaler
from joblib import dump
from pathlib import Path

# %%
file_path = Path("resources/movies.csv")
df_movie = pd.read_csv(file_path)

# %%
df_movie["released"] = df_movie["released"].str.split("\s+\(").str[0]
#df_movie["released_country"] = df_movie["released"].str.split("\s+\(").str[1]
df_movie["released"] = pd.to_datetime(df_movie['released'])

# %%
df_movie ["released"] = df_movie["released"].dt.month_name()

# %%
df_movie.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#   released  score      votes         director                   writer  \
# 0     June    8.4   927000.0  Stanley Kubrick             Stephen King
# 1     July    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2     June    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3     July    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4     July    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
#              star         country      budget        gross  \
# 0  Jack Nicholson  United Kingdom  19000000.0   46998772.0
# 1  Brooke Shields   United States   4500000.0   58853106.0
# 2     Mark Hamill   United States  18000000.0  538375067.0
# 3     Robert Hays   United States   3500000.0   83453539.0
# 4     Chevy Chase   United States   6000000.0   39846344.0
#
#               company  runtime
# 0        Warner Bros.    146.0
# 1   Columbia Pictures    104.0
# 2           Lucasfilm    124.0
# 3  Paramount Pictures     88.0
# 4      Orion Pictures     98.0

# %%
df_movie = df_movie.drop(columns=['score', 'votes'])

# %%
df_movie.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#   released         director                   writer            star  \
# 0     June  Stanley Kubrick             Stephen King  Jack Nicholson
# 1     July   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 2     June   Irvin Kershner           Leigh Brackett     Mark Hamill
# 3     July     Jim Abrahams             Jim Abrahams     Robert Hays
# 4     July     Harold Ramis       Brian Doyle-Murray     Chevy Chase
#
#           country      budget        gross             company  runtime
# 0  United Kingdom  19000000.0   46998772.0        Warner Bros.    146.0
# 1   United States   4500000.0   58853106.0   Columbia Pictures    104.0
# 2   United States  18000000.0  538375067.0           Lucasfilm    124.0
# 3   United States   3500000.0   83453539.0  Paramount Pictures     88.0
# 4   United States   6000000.0   39846344.0      Orion Pictures     98.0

# %%
df_movie['trixbudget']= df_movie['gross'] - 2*df_movie['budget']

# %%
df_movie = df_movie.dropna()

# %%
df_movie.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#   released         director                   writer            star  \
# 0     June  Stanley Kubrick             Stephen King  Jack Nicholson
# 1     July   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 2     June   Irvin Kershner           Leigh Brackett     Mark Hamill
# 3     July     Jim Abrahams             Jim Abrahams     Robert Hays
# 4     July     Harold Ramis       Brian Doyle-Murray     Chevy Chase
#
#           country      budget        gross             company  runtime  \
# 0  United Kingdom  19000000.0   46998772.0        Warner Bros.    146.0
# 1   United States   4500000.0   58853106.0   Columbia Pictures    104.0
# 2   United States  18000000.0  538375067.0           Lucasfilm    124.0
# 3   United States   3500000.0   83453539.0  Paramount Pictures     88.0
# 4   United States   6000000.0   39846344.0      Orion Pictures     98.0
#
#     trixbudget
# 0    8998772.0
# 1   49853106.0
# 2  502375067.0
# 3   76453539.0
# 4   27846344.0

# %%
df_movie['success'] = df_movie['trixbudget'].map(lambda x: x>0).astype(int)

# %%
df_movie.sort_values(by="gross", ascending=True)
# Out:
#                                             name     rating   genre  year  \
# 3203                                  Trojan War      PG-13  Comedy  1997
# 272                                     Parasite          R  Horror  1982
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 5640                                 Tanner Hall          R   Drama  2009
# ...                                          ...        ...     ...   ...
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 3045                                     Titanic      PG-13   Drama  1997
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 5445                                      Avatar      PG-13  Action  2009
#
#       released             director                   writer  \
# 3203   October         George Huang                Andy Burg
# 272      March         Charles Band            Alan J. Adler
# 3681       May         John Fawcett             Karen Walton
# 2434      June     Stephen Cornwell       Wallace C. Bennett
# 5640   January  Francesca Gregorini  Tatiana von Fürstenberg
# ...        ...                  ...                      ...
# 7244     April        Anthony Russo       Christopher Markus
# 6663  December          J.J. Abrams          Lawrence Kasdan
# 3045  December        James Cameron            James Cameron
# 7445     April        Anthony Russo       Christopher Markus
# 5445  December        James Cameron            James Cameron
#
#                    star        country       budget         gross  \
# 3203       Will Friedle  United States   15000000.0  3.090000e+02
# 272     Robert Glaudini  United States     800000.0  2.270000e+03
# 3681      Emily Perkins         Canada    5000000.0  2.554000e+03
# 2434       Brad Johnson  United States    5000000.0  2.970000e+03
# 5640        Rooney Mara  United States    3000000.0  5.073000e+03
# ...                 ...            ...          ...           ...
# 7244  Robert Downey Jr.  United States  321000000.0  2.048360e+09
# 6663       Daisy Ridley  United States  245000000.0  2.069522e+09
# 3045  Leonardo DiCaprio  United States  200000000.0  2.201647e+09
# 7445  Robert Downey Jr.  United States  356000000.0  2.797501e+09
# 5445    Sam Worthington  United States  237000000.0  2.847246e+09
#
#                         company  runtime    trixbudget  success
# 3203                   Daybreak     85.0 -2.999969e+07        0
# 272            Embassy Pictures     85.0 -1.597730e+06        0
# 3681  Copperheart Entertainment    108.0 -9.997446e+06        0
# 2434           Trimark Pictures     97.0 -9.997030e+06        0
# 5640           Two Prong Lesson     96.0 -5.994927e+06        0
# ...                         ...      ...           ...      ...
# 7244             Marvel Studios    149.0  1.406360e+09        1
# 6663                  Lucasfilm    138.0  1.579522e+09        1
# 3045      Twentieth Century Fox    194.0  1.801647e+09        1
# 7445             Marvel Studios    181.0  2.085501e+09        1
# 5445      Twentieth Century Fox    162.0  2.373246e+09        1
#
# [5421 rows x 15 columns]

# %%
df_movie_success = df_movie.loc[df_movie['success'] == 1]

df_movie_failed = df_movie.loc[df_movie['success'] == 0]

# %%
df_movie_success.tail()
# Out:
#                     name     rating   genre  year  released        director  \
# 7645       Birds of Prey          R  Action  2020  February       Cathy Yan
# 7646   The Invisible Man          R   Drama  2020  February  Leigh Whannell
# 7648   Bad Boys for Life          R  Action  2020   January    Adil El Arbi
# 7649  Sonic the Hedgehog         PG  Action  2020  February     Jeff Fowler
# 7652   The Eight Hundred  Not Rated  Action  2020    August         Hu Guan
#
#                 writer             star        country      budget  \
# 7645  Christina Hodson    Margot Robbie  United States  84500000.0
# 7646    Leigh Whannell   Elisabeth Moss         Canada   7000000.0
# 7648       Peter Craig       Will Smith  United States  90000000.0
# 7649         Pat Casey     Ben Schwartz  United States  85000000.0
# 7652           Hu Guan  Zhi-zhong Huang          China  80000000.0
#
#             gross                              company  runtime   trixbudget  \
# 7645  201858461.0              Clubhouse Pictures (II)    109.0   32858461.0
# 7646  143151000.0                   Universal Pictures    124.0  129151000.0
# 7648  426505244.0                    Columbia Pictures    124.0  246505244.0
# 7649  319715683.0                   Paramount Pictures     99.0  149715683.0
# 7652  461421559.0  Beijing Diqi Yinxiang Entertainment    149.0  301421559.0
#
#       success
# 7645        1
# 7646        1
# 7648        1
# 7649        1
# 7652        1

# %%
df_movie
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year  released         director                   writer  \
# 0     1980      June  Stanley Kubrick             Stephen King
# 1     1980      July   Randal Kleiser  Henry De Vere Stacpoole
# 2     1980      June   Irvin Kershner           Leigh Brackett
# 3     1980      July     Jim Abrahams             Jim Abrahams
# 4     1980      July     Harold Ramis       Brian Doyle-Murray
# ...    ...       ...              ...                      ...
# 7648  2020   January     Adil El Arbi              Peter Craig
# 7649  2020  February      Jeff Fowler                Pat Casey
# 7650  2020   January   Stephen Gaghan           Stephen Gaghan
# 7651  2020  February    Chris Sanders            Michael Green
# 7652  2020    August          Hu Guan                  Hu Guan
#
#                    star         country       budget        gross  \
# 0        Jack Nicholson  United Kingdom   19000000.0   46998772.0
# 1        Brooke Shields   United States    4500000.0   58853106.0
# 2           Mark Hamill   United States   18000000.0  538375067.0
# 3           Robert Hays   United States    3500000.0   83453539.0
# 4           Chevy Chase   United States    6000000.0   39846344.0
# ...                 ...             ...          ...          ...
# 7648         Will Smith   United States   90000000.0  426505244.0
# 7649       Ben Schwartz   United States   85000000.0  319715683.0
# 7650  Robert Downey Jr.   United States  175000000.0  245487753.0
# 7651      Harrison Ford          Canada  135000000.0  111105497.0
# 7652    Zhi-zhong Huang           China   80000000.0  461421559.0
#
#                                   company  runtime   trixbudget  success
# 0                            Warner Bros.    146.0    8998772.0        1
# 1                       Columbia Pictures    104.0   49853106.0        1
# 2                               Lucasfilm    124.0  502375067.0        1
# 3                      Paramount Pictures     88.0   76453539.0        1
# 4                          Orion Pictures     98.0   27846344.0        1
# ...                                   ...      ...          ...      ...
# 7648                    Columbia Pictures    124.0  246505244.0        1
# 7649                   Paramount Pictures     99.0  149715683.0        1
# 7650                   Universal Pictures    101.0 -104512247.0        0
# 7651                 20th Century Studios    100.0 -158894503.0        0
# 7652  Beijing Diqi Yinxiang Entertainment    149.0  301421559.0        1
#
# [5421 rows x 15 columns]

# %%
df_movie.nunique()
# Out:
# name          5336
# rating          10
# genre           15
# year            41
# released        12
# director      2063
# writer        3205
# star          1845
# country         50
# budget         398
# gross         5418
# company       1475
# runtime        127
# trixbudget    5421
# success          2
# dtype: int64

# %%
df_movie_failed.nunique()
# Out:
# name          2829
# rating           9
# genre           15
# year            41
# released        12
# director      1522
# writer        2129
# star          1257
# country         38
# budget         281
# gross         2853
# company       1022
# runtime        113
# trixbudget    2854
# success          1
# dtype: int64

# %%
from pathlib import Path  
filepath = Path('Resources/clean_movies.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_movie.to_csv(filepath)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21660\3642907371.py in <module>
#       2 filepath = Path('Resources/clean_movies.csv')
#       3 filepath.parent.mkdir(parents=True, exist_ok=True)
# ----> 4 df_movie.to_csv(filepath)
#
# ~\anaconda\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~\anaconda\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~\anaconda\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# PermissionError: [Errno 13] Permission denied: 'Resources\\clean_movies.csv'
